# %% [markdown]
# # SentryMesh Guardian: Multi-Label Cognitive Tactic Model Training
#
# This notebook trains the multi-label tactic predictor from `data/raw/sentrymesh_tactics.csv`.
#
# ### Core Psychological Levers Tracked:
# - `authority_impersonation`
# - `urgency`
# - `fear_or_threat`
# - `secrecy`
# - `isolation`
# - `payment_request`
# - `otp_request`
# - `credential_request`
# - `remote_access_request`
# - `screen_share_request`
# - `upi_collect_request`
#
# Tactics are converted to calibrated probability vectors passed directly into the **Explain** stage of the SentryMesh lifecycle.

# %%
# !pip install -q sentence-transformers scikit-learn joblib pandas numpy
import sys
sys.path.append("..")
from scripts.train_tactic_model import train_tactic_model

trained_tactics = train_tactic_model()
print("Tactic training completed for vectors:", trained_tactics)
